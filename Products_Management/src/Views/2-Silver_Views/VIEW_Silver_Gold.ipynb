# %%
# %sql
create or replace view product_silver_gold as
(
  select
    product_name,
    product_unit,
    start_date_price,
    end_date_price,
    price_currency,
    market_name,
    city,
    department,
    start_date_market,
    end_date_market
  from
    products.silver.product_list_silver
  where
    start_date_market >= '2024-12-01'
)
