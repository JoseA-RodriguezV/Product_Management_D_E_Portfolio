# %% [markdown]
# # **ETL SEMANTICA**

# %%
# %sql
--Actual Price Difference between start date and end date
-- Ver diferencia de Precios
select * from products.semantica.gold_data

# %%
# %sql
-- Actual Highest Market All Products Price by Department
-- Ver cual es la canasta basica mas cara x mercado y depto
select * from products.semantica.vw_price_weekly_variation

# %%
# %sql
-- Evolution Historical Prices
select * from products.semantica.vw_market_price_ranking

# %%
# %sql
select * from products.semantica.vw_product_historical_trends 
order by product_name, market_name,year_week

# %%
# %sql
select * from products.semantica.vw_seasonal_price_analysis
