# %% [markdown]
# # **EDA SILVER ANALYSIS**

# %%
# %sql
DESCRIBE TABLE EXTENDED products.silver.product_list_silver

# %%
# %sql
select count(*) from products.silver.product_list_silver

# %%
# %sql
SELECT '1. Bronze' AS layer, count(*) FROM products.bronze.product_list_markets_bronze
UNION ALL
SELECT '2. Silver' AS layer, count(*) FROM products.silver.product_list_silver

ORDER BY layer;
