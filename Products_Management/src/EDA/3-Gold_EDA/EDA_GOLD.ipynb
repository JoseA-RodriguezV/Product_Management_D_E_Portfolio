# %% [markdown]
# # **EDA GOLD ANALYSIS**

# %%
# %sql
DESCRIBE TABLE EXTENDED products.gold.fact_product_prices

# %%
# %sql
select count(*) from products.gold.fact_product_prices

# %%
# %sql
SELECT '1. Bronze' AS layer, count(*) FROM products.bronze.product_list_markets_bronze
UNION ALL
SELECT '2. Silver' AS layer, count(*) FROM products.silver.product_list_silver
UNION ALL
SELECT '3. Gold' AS layer, count(*) FROM products.gold.fact_product_prices
ORDER BY layer;
