# %% [markdown]
# # **MARKET DIMENSION**
#
# DDL for Market Dimension Table in Gold Layer

# %%
# %sql
DROP TABLE IF EXISTS products.gold.dim_market;

create table products.gold.dim_market (
    market_id BIGINT
      GENERATED ALWAYS AS IDENTITY (START WITH 1 INCREMENT BY 1)
      PRIMARY KEY
      COMMENT 'Market ID',
    market_name STRING COMMENT 'Market Name.',
    city STRING COMMENT 'City name where the Market is located.',
    department STRING COMMENT 'Department name where the city Market is located.',
    _created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP()
  ) USING DELTA
  TBLPROPERTIES ('delta.feature.allowColumnDefaults' = 'supported')
  COMMENT 'Market Dimension - Star Schema';
