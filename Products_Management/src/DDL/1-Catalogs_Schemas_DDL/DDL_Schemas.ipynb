# %% [markdown]
# # **Create Schemas for Project**

# %%
# %sql

--Create main catalog
create catalog products

# %%
# %sql
-- Validating created catalog
use catalog products

# %%
# %sql
-- creating bronze layer 

create schema if not exists products.bronze
comment 'Schema for casted data in Raw data from Source'

# %%
# %sql
--create silver layer

create schema if not exists products.silver
comment 'Schema for casted data in Silver layer from Bronce layer'

# %%
# %sql
--create gold layer

create schema if not exists products.gold
comment 'Schema for casted data in Gold layer from Silver layer'

# %%
# %sql
--create semantica layer

create schema if not exists products.semantica
comment 'Schema for views for BI'

# %%
# %sql

--validating created schemas for medallion architecture
USE CATALOG products;
SHOW SCHEMAS;
